# %%
# !pip install obsei[all]
# Out:
# Requirement already satisfied: obsei[all] in d:\anaconda\lib\site-packages (0.0.15)
# Requirement already satisfied: mmh3>=4.0.1 in d:\anaconda\lib\site-packages (from obsei[all]) (4.1.0)
# Requirement already satisfied: requests>=2.26.0 in d:\anaconda\lib\site-packages (from obsei[all]) (2.28.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from obsei[all]) (2.8.2)
# Requirement already satisfied: pydantic-settings>=2.1.0 in d:\anaconda\lib\site-packages (from obsei[all]) (2.2.1)
# Requirement already satisfied: dateparser>=1.2.0 in d:\anaconda\lib\site-packages (from obsei[all]) (1.2.0)
# Requirement already satisfied: pydantic>=2.5.3 in d:\anaconda\lib\site-packages (from obsei[all]) (2.7.1)
# Requirement already satisfied: sqlalchemy>=2.0.24 in d:\anaconda\lib\site-packages (from obsei[all]) (2.0.29)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in d:\anaconda\lib\site-packages (from obsei[all]) (4.11.1)
# Requirement already satisfied: pytz>=2023.3.post1 in d:\anaconda\lib\site-packages (from obsei[all]) (2024.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.9.3->obsei[all]) (2.3.1)
# Requirement already satisfied: tzlocal in d:\anaconda\lib\site-packages (from dateparser>=1.2.0->obsei[all]) (5.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in d:\anaconda\lib\site-packages (from dateparser>=1.2.0->obsei[all]) (2022.7.9)
# Requirement already satisfied: pydantic-core==2.18.2 in d:\anaconda\lib\site-packages (from pydantic>=2.5.3->obsei[all]) (2.18.2)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic>=2.5.3->obsei[all]) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\anaconda\lib\site-packages (from pydantic>=2.5.3->obsei[all]) (4.11.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\anaconda\lib\site-packages (from pydantic-settings>=2.1.0->obsei[all]) (1.0.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->obsei[all]) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.26.0->obsei[all]) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests>=2.26.0->obsei[all]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.26.0->obsei[all]) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.26.0->obsei[all]) (3.3)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\lib\site-packages (from sqlalchemy>=2.0.24->obsei[all]) (1.1.1)
# Collecting nltk>=3.8.1
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 4.6 MB/s eta 0:00:00
# Collecting presidio-analyzer>=2.2.351
#   Downloading presidio_analyzer-2.2.354-py3-none-any.whl (92 kB)
#      -------------------------------------- 92.2/92.2 kB 655.3 kB/s eta 0:00:00
# Collecting torch>=2.1.2
#   Downloading torch-2.3.0-cp39-cp39-win_amd64.whl (159.7 MB)
#      -------------------------------------- 159.7/159.7 MB 2.0 MB/s eta 0:00:00
# Collecting presidio-anonymizer>=2.2.351
#   Downloading presidio_anonymizer-2.2.354-py3-none-any.whl (31 kB)
# Collecting transformers>=4.36.2
#   Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#      ---------------------------------------- 9.0/9.0 MB 1.2 MB/s eta 0:00:00
# Collecting spacy>=3.7.2
#   Downloading spacy-3.7.4-cp39-cp39-win_amd64.whl (12.2 MB)
#      ---------------------------------------- 12.2/12.2 MB 4.5 MB/s eta 0:00:00
# Collecting sentencepiece>=0.1.99
#   Downloading sentencepiece-0.2.0-cp39-cp39-win_amd64.whl (991 kB)
#      -------------------------------------- 991.5/991.5 kB 6.3 MB/s eta 0:00:00
# Collecting vadersentiment>=3.3.2
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      -------------------------------------- 126.0/126.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from nltk>=3.8.1->obsei[all]) (4.64.1)
# Requirement already satisfied: click in d:\anaconda\lib\site-packages (from nltk>=3.8.1->obsei[all]) (8.0.4)
# Requirement already satisfied: joblib in d:\anaconda\lib\site-packages (from nltk>=3.8.1->obsei[all]) (1.1.0)
# Requirement already satisfied: tldextract in d:\anaconda\lib\site-packages (from presidio-analyzer>=2.2.351->obsei[all]) (3.2.0)
# Collecting phonenumbers<9.0.0,>=8.12
#   Downloading phonenumbers-8.13.36-py2.py3-none-any.whl (2.6 MB)
#      ---------------------------------------- 2.6/2.6 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from presidio-analyzer>=2.2.351->obsei[all]) (6.0)
# Collecting pycryptodome>=3.10.1
#   Downloading pycryptodome-3.20.0-cp35-abi3-win_amd64.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 5.3 MB/s eta 0:00:00
# Collecting typer<0.10.0,>=0.3.0
#   Downloading typer-0.9.4-py3-none-any.whl (45 kB)
#      -------------------------------------- 46.0/46.0 kB 760.3 kB/s eta 0:00:00
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from spacy>=3.7.2->obsei[all]) (2.11.3)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp39-cp39-win_amd64.whl (39 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#      -------------------------------------- 182.0/182.0 kB 3.7 MB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from spacy>=3.7.2->obsei[all]) (63.4.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda\lib\site-packages (from spacy>=3.7.2->obsei[all]) (5.2.1)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp39-cp39-win_amd64.whl (25 kB)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from spacy>=3.7.2->obsei[all]) (21.3)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp39-cp39-win_amd64.whl (122 kB)
#      -------------------------------------- 122.7/122.7 kB 2.4 MB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp39-cp39-win_amd64.whl (483 kB)
#      ------------------------------------- 483.8/483.8 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.0 in d:\anaconda\lib\site-packages (from spacy>=3.7.2->obsei[all]) (1.21.5)
# Collecting weasel<0.4.0,>=0.1.0
#   Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#      -------------------------------------- 50.1/50.1 kB 511.1 kB/s eta 0:00:00
# Collecting thinc<8.3.0,>=8.2.2
#   Downloading thinc-8.2.3-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 5.3 MB/s eta 0:00:00
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from torch>=2.1.2->obsei[all]) (3.6.0)
# Requirement already satisfied: fsspec in d:\anaconda\lib\site-packages (from torch>=2.1.2->obsei[all]) (2022.7.1)
# Collecting mkl<=2021.4.0,>=2021.1.1
#   Downloading mkl-2021.4.0-py2.py3-none-win_amd64.whl (228.5 MB)
#      ------------------------------------ 228.5/228.5 MB 624.9 kB/s eta 0:00:00
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (from torch>=2.1.2->obsei[all]) (2.8.4)
# Requirement already satisfied: sympy in d:\anaconda\lib\site-packages (from torch>=2.1.2->obsei[all]) (1.10.1)
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.4.3-cp39-none-win_amd64.whl (287 kB)
#      -------------------------------------- 287.9/287.9 kB 3.0 MB/s eta 0:00:00
# Collecting tokenizers<0.20,>=0.19
#   Downloading tokenizers-0.19.1-cp39-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 4.3 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0,>=0.19.3
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      -------------------------------------- 401.2/401.2 kB 4.2 MB/s eta 0:00:00
# Collecting searchtweets-v2>=1.1.1
#   Downloading searchtweets_v2-1.1.1-py3-none-any.whl (32 kB)
# Collecting google-api-python-client>=2.111.0
#   Downloading google_api_python_client-2.127.0-py2.py3-none-any.whl (12.7 MB)
#      ---------------------------------------- 12.7/12.7 MB 4.1 MB/s eta 0:00:00
# Collecting app-store-reviews-reader>=1.2
#   Downloading app_store_reviews_reader-1.2-py3-none-any.whl (8.4 kB)
# Collecting google-play-scraper>=1.2.4
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Collecting elasticsearch>=8.11.1
#   Downloading elasticsearch-8.13.1-py3-none-any.whl (477 kB)
#      -------------------------------------- 477.5/477.5 kB 3.7 MB/s eta 0:00:00
# Collecting pandas>=2.0.3
#   Downloading pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 4.5 MB/s eta 0:00:00
# Collecting atlassian-python-api>=3.41.4
#   Downloading atlassian_python_api-3.41.11-py3-none-any.whl (173 kB)
#      -------------------------------------- 173.3/173.3 kB 2.1 MB/s eta 0:00:00
# Collecting slack-sdk>=3.26.1
#   Downloading slack_sdk-3.27.1-py2.py3-none-any.whl (285 kB)
#      -------------------------------------- 285.7/285.7 kB 4.4 MB/s eta 0:00:00
# Collecting googlenews>=1.6.12
#   Downloading GoogleNews-1.6.14-py3-none-any.whl (8.5 kB)
# Collecting python-facebook-api>=0.15.0
#   Downloading python_facebook_api-0.19.0-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# Collecting praw>=7.7.1
#   Downloading praw-7.7.1-py3-none-any.whl (191 kB)
#      ------------------------------------ 191.0/191.0 kB 890.5 kB/s eta 0:00:00
# Collecting reddit-rss-reader>=1.3.2
#   Downloading reddit_rss_reader-1.3.2-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: tzdata in d:\anaconda\lib\site-packages (from tzlocal->dateparser>=1.2.0->obsei[all]) (2024.1)
# Collecting feedparser
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ---------------------------------------- 81.3/81.3 kB 2.3 MB/s eta 0:00:00
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting oauthlib
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Collecting deprecated
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: jmespath in d:\anaconda\lib\site-packages (from atlassian-python-api>=3.41.4->obsei[all]) (0.10.0)
# Collecting elastic-transport<9,>=8.13
#   Downloading elastic_transport-8.13.0-py3-none-any.whl (64 kB)
#      -------------------------------------- 64.3/64.3 kB 857.5 kB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5
#   Downloading google_api_core-2.19.0-py3-none-any.whl (139 kB)
#      -------------------------------------- 139.0/139.0 kB 1.7 MB/s eta 0:00:00
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0
#   Downloading google_auth-2.29.0-py2.py3-none-any.whl (189 kB)
#      ------------------------------------ 189.2/189.2 kB 260.1 kB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting httplib2<1.dev0,>=0.19.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      -------------------------------------- 96.9/96.9 kB 921.4 kB/s eta 0:00:00
# Collecting google-auth-httplib2<1.0.0,>=0.2.0
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Collecting fsspec
#   Downloading fsspec-2024.3.1-py3-none-any.whl (171 kB)
#      ------------------------------------ 172.0/172.0 kB 860.4 kB/s eta 0:00:00
# Collecting language-data>=1.2
#   Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#      ---------------------------------------- 5.4/5.4 MB 4.8 MB/s eta 0:00:00
# Collecting intel-openmp==2021.*
#   Downloading intel_openmp-2021.4.0-py2.py3-none-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 5.0 MB/s eta 0:00:00
# Collecting tbb==2021.*
#   Downloading tbb-2021.12.0-py3-none-win_amd64.whl (286 kB)
#      -------------------------------------- 286.4/286.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\anaconda\lib\site-packages (from packaging>=20.0->spacy>=3.7.2->obsei[all]) (3.0.9)
# Collecting numpy>=1.19.0
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#      ---------------------------------------- 15.8/15.8 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client>=0.54.0 in d:\anaconda\lib\site-packages (from praw>=7.7.1->obsei[all]) (0.58.0)
# Collecting update-checker>=0.18
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting prawcore<3,>=2.1
#   Downloading prawcore-2.4.0-py3-none-any.whl (17 kB)
# Collecting requests-oauthlib
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp39-cp39-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 2.0 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm->nltk>=3.8.1->obsei[all]) (0.4.5)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#      -------------------------------------- 45.0/45.0 kB 561.0 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->spacy>=3.7.2->obsei[all]) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in d:\anaconda\lib\site-packages (from sympy->torch>=2.1.2->obsei[all]) (1.2.1)
# Requirement already satisfied: requests-file>=1.4 in d:\anaconda\lib\site-packages (from tldextract->presidio-analyzer>=2.2.351->obsei[all]) (1.5.1)
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      -------------------------------------- 49.3/49.3 kB 156.2 kB/s eta 0:00:00
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#      -------------------------------------- 48.8/48.8 kB 611.7 kB/s eta 0:00:00
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5
#   Downloading protobuf-4.25.3-cp39-cp39-win_amd64.whl (413 kB)
#      -------------------------------------- 413.4/413.4 kB 1.8 MB/s eta 0:00:00
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#      -------------------------------------- 229.1/229.1 kB 1.8 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=2.111.0->obsei[all]) (0.2.8)
# Collecting marisa-trie>=0.7.7
#   Downloading marisa_trie-1.1.0-cp39-cp39-win_amd64.whl (152 kB)
#      -------------------------------------- 152.5/152.5 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in d:\anaconda\lib\site-packages (from deprecated->atlassian-python-api>=3.41.4->obsei[all]) (1.14.1)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client>=2.111.0->obsei[all]) (0.4.8)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\anaconda\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->python-facebook-api>=0.15.0->obsei[all]) (0.4.3)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py): started
#   Building wheel for sgmllib3k (setup.py): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=1df1bc325938ea08c31220c3f172d9af0a25482ff033ca0959bf751a068efa3b
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\65\7a\a7\78c287f64e401255dff4c13fdbc672fed5efbfd21c530114e1
# Successfully built sgmllib3k
# Installing collected packages: tbb, sgmllib3k, sentencepiece, phonenumbers, intel-openmp, cymem, uritemplate, typing-inspect, spacy-loggers, spacy-legacy, slack-sdk, safetensors, rsa, pycryptodome, protobuf, oauthlib, numpy, murmurhash, mkl, marisa-trie, httplib2, google-play-scraper, fsspec, feedparser, elastic-transport, deprecated, colorama, cloudpathlib, catalogue, cachetools, wasabi, vadersentiment, update-checker, torch, srsly, searchtweets-v2, requests-oauthlib, reddit-rss-reader, proto-plus, presidio-anonymizer, preshed, prawcore, pandas, marshmallow, language-data, googleapis-common-protos, google-auth, elasticsearch, blis, app-store-reviews-reader, typer, praw, nltk, langcodes, huggingface-hub, googlenews, google-auth-httplib2, google-api-core, dataclasses-json, confection, atlassian-python-api, weasel, tokenizers, thinc, python-facebook-api, google-api-python-client, transformers, spacy, presidio-analyzer
#   Attempting uninstall: tbb
#     Found existing installation: TBB 0.2
# ERROR: Cannot uninstall 'TBB'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.

# %%
import logging
import sys

from obsei.analyzer.classification_analyzer import (
    ClassificationAnalyzerConfig, ZeroShotClassificationAnalyzer)
from obsei.source.youtube_scrapper import (YoutubeScrapperConfig,
                                           YoutubeScrapperSource)

logger = logging.getLogger(__name__)
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

source_config = YoutubeScrapperConfig(
    video_url="https://www.youtube.com/watch?v=uZfns0JIlFk",
    fetch_replies=True,
    max_comments=10,
    lookup_period="1Y",
)

source = YoutubeScrapperSource()

source_response_list = source.lookup(source_config)
for idx, source_response in enumerate(source_response_list):
    logger.info(f"source_response#'{idx}'='{source_response.__dict__}'")

text_analyzer = ZeroShotClassificationAnalyzer(
    model_name_or_path="typeform/mobilebert-uncased-mnli", device="auto"
)

analyzer_response_list = text_analyzer.analyze_input(
    source_response_list=source_response_list,
    analyzer_config=ClassificationAnalyzerConfig(
        labels=["interesting", "enquiring"],
    ),
)
for idx, an_response in enumerate(analyzer_response_list):
    logger.info(f"analyzer_response#'{idx}'='{an_response.__dict__}'")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15664\1602210751.py in <module>
#       2 import sys
#       3
# ----> 4 from obsei.analyzer.classification_analyzer import (
#       5     ClassificationAnalyzerConfig, ZeroShotClassificationAnalyzer)
#       6 from obsei.source.youtube_scrapper import (YoutubeScrapperConfig,
#
# D:\anaconda\lib\site-packages\obsei\analyzer\classification_analyzer.py in <module>
#       3
#       4 from pydantic import Field, PrivateAttr
# ----> 5 from transformers import Pipeline, pipeline
#       6
#       7 from obsei.analyzer.base_analyzer import (
#
# ModuleNotFoundError: No module named 'transformers'
